# %%
# Importing libraries
# Also uploading file

import pandas as pd
import numpy as np

# %%
# Assigning file an easy name

industry = pd.read_csv('industryAnalysis_2000_2022.csv')

# %%
# Displaying file

display(industry)
# Out:
#          gvkey  datadate   fyear indfmt consol popsrc datafmt   tic  \
# 0         1004  20010531  2000.0   INDL      C      D     STD   AIR
# 1         1004  20020531  2001.0   INDL      C      D     STD   AIR
# 2         1004  20030531  2002.0   INDL      C      D     STD   AIR
# 3         1004  20040531  2003.0   INDL      C      D     STD   AIR
# 4         1004  20050531  2004.0   INDL      C      D     STD   AIR
# ...        ...       ...     ...    ...    ...    ...     ...   ...
# 254548  345980  20191231  2019.0   INDL      C      D     STD  WISH
# 254549  345980  20201231  2020.0   INDL      C      D     STD  WISH
# 254550  347085  20190228  2018.0   INDL      C      D     STD  KARO
# 254551  347085  20200229  2019.0   INDL      C      D     STD  KARO
# 254552  347085  20210228  2020.0   INDL      C      D     STD  KARO
#
#                     conm curcd  ...        at     cogs     csho    emp  \
# 0               AAR CORP   USD  ...   701.854  713.811   26.937  2.500
# ...

# %%
# Applying filters to file for naics code 454110 and for the fiscal year 2018
# Also only keeping the needed columns

industry.loc[(industry['naics'] == 454110)&(industry['fyear'] == 2018),['tic','conm','at','naics','fyear']]
# Out:
#           tic                          conm          at     naics   fyear
# 30718     WSM           WILLIAMS-SONOMA INC    2812.844  454110.0  2018.0
# 33503    KSPN          KASPIEN HOLDINGS INC     138.013  454110.0  2018.0
# 37383   0189A                       QVC INC   14856.000  454110.0  2018.0
# 54693    LITB      LIGHTINTHEBOX HLDG  -ADR     103.587  454110.0  2018.0
# 61285      LE                LANDS' END INC    1110.911  454110.0  2018.0
# 61735      JD                    JD.COM INC   30411.441  454110.0  2018.0
# 64100    JMEI  JUMEI INTL HOLDING LTD  -ADR     747.649  454110.0  2018.0
# 66871    RMBL                  RUMBLEON INC     108.926  454110.0  2018.0
# 68352       W                   WAYFAIR INC    1890.850  454110.0  2018.0
# 74543    BZUN                    BAOZUN INC     583.879  454110.0  2018.0
# 76209    IMBI             IMEDIA BRANDS INC     229.987  454110.0  2018.0
# 85850    DLTH           DULUTH HOLDINGS INC     296.759  454110.0  2018.0
# ...

# %%
# Assigning a name to the filtered file

naics_454110 = industry.loc[(industry['naics'] == 454110)&(industry['fyear'] == 2018),['tic','conm','at','naics','fyear']]

# %%
# Seeing the assigned file to make sure it works

naics_454110
# Out:
#           tic                          conm          at     naics   fyear
# 30718     WSM           WILLIAMS-SONOMA INC    2812.844  454110.0  2018.0
# 33503    KSPN          KASPIEN HOLDINGS INC     138.013  454110.0  2018.0
# 37383   0189A                       QVC INC   14856.000  454110.0  2018.0
# 54693    LITB      LIGHTINTHEBOX HLDG  -ADR     103.587  454110.0  2018.0
# 61285      LE                LANDS' END INC    1110.911  454110.0  2018.0
# 61735      JD                    JD.COM INC   30411.441  454110.0  2018.0
# 64100    JMEI  JUMEI INTL HOLDING LTD  -ADR     747.649  454110.0  2018.0
# 66871    RMBL                  RUMBLEON INC     108.926  454110.0  2018.0
# 68352       W                   WAYFAIR INC    1890.850  454110.0  2018.0
# 74543    BZUN                    BAOZUN INC     583.879  454110.0  2018.0
# 76209    IMBI             IMEDIA BRANDS INC     229.987  454110.0  2018.0
# 85850    DLTH           DULUTH HOLDINGS INC     296.759  454110.0  2018.0
# ...

# %%
# Using describe to find the mean of at(Total Assets) for the filtered file

naics_454110.describe()
# Out:
#                   at     naics   fyear
# count      46.000000      51.0    51.0
# mean     5477.830500  454110.0  2018.0
# std     24312.446889       0.0     0.0
# min         0.032000  454110.0  2018.0
# 25%       140.359500  454110.0  2018.0
# 50%       471.402000  454110.0  2018.0
# 75%       740.974250  454110.0  2018.0
# max    162648.000000  454110.0  2018.0

# %%
# Above we can see that the mean of at(Total Assets) of companies with the naics
#   code 454110 for the fyear(fiscal year) 2018 is 5477.8305
